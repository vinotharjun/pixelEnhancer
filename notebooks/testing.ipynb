# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")
from enhancer import *
from enhancer.data.testdataset import * 
from enhancer.utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data =  TestDataset("../inference_folder/final1","../inference_folder/frames1")

# %%
versus_plot(
    data[1]["predicted"],
    data[1]["target"],
    preupscaling=False,
    figsize=(10, 10),
    denormalize=False,
)

# %%
total_ssim = 0.0
len_data= len(data)
for i in data:
    total_ssim += ssim(i["predicted"],i["target"]).item()
print(total_ssim/len_data)
# Out:
# 0.9430180013179779
