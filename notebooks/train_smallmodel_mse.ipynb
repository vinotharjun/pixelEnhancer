# %%
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload 2

# %%
from enhancer import *
from enhancer.options import *
from enhancer.data import * 
from enhancer.utils import *

# %%
opt_path = "../configs/smallmodel/mse_train.yml"
# dataloaders = get_dataloader_from_yml(opt_path)
pipeline =load_pipeline_from_yml("../configs/smallmodel/mse_train.yml")
# Out:
# loading checkpoint from  ../checkpoints/small_checkpoint_mse_noise.pt
# Info :check point details are
#  epoch : 92
#  batch : 90

# %%
batch_example = getsample(pipeline["loaders"]["train_dataloader"])

# %%
280/4
# Out:
# 70.0

# %%
batch_example["lr"].shape,batch_example["hr"].shape
# Out:
# (torch.Size([16, 3, 70, 70]), torch.Size([16, 3, 280, 280]))

# %%
# batch_versus_plot(
#     batch_example["lr"],
#     batch_example["hr"],
#     preupscaling=True,
#     figsize = (10,10),
#     denormalize=False,
#     batch_limit = 4
# )

# %%
pipeline["trainer"].train_model(1,300)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='39' class='' max='299' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       13.04% [39/299 4:39:21<31:02:21]
#     </div>
#
# checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [0/221] content loss :1.1053375005722046<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [10/221] content loss :1.102735698223114<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [20/221] content loss :1.0848888158798218<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [30/221] content loss :1.0918293178081513<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [40/221] content loss :1.087059462070465<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [50/221] content loss :1.0826518297195435<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [60/221] content loss :1.071309232711792<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [70/221] content loss :1.0806233882904053<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [80/221] content loss :1.0851217031478881<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [90/221] content loss :1.102424967288971<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [100/221] content loss :1.0819056630134583<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [110/221] content loss :1.0967476844787598<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [120/221] content loss :1.0926979660987854<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [130/221] content loss :1.0873072743415833<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [140/221] content loss :1.0823551177978517<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [150/221] content loss :1.0712222635746003<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [160/221] content loss :1.107716190814972<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [170/221] content loss :1.1357858657836915<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [180/221] content loss :1.0932272493839263<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [190/221] content loss :1.1067150115966797<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [200/221] content loss :1.097007304430008<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [210/221] content loss :1.0521836161613465<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 1 [220/221] content loss :1.080378532409668<p>
# Epoch: 1 average content loss 1.0897931178770455<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [0/221] content loss :1.117154598236084<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [10/221] content loss :1.0684594929218292<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [20/221] content loss :1.1144392132759093<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [30/221] content loss :1.0933777928352355<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [40/221] content loss :1.1045519351959228<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [50/221] content loss :1.0905942082405091<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [60/221] content loss :1.074650126695633<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [70/221] content loss :1.067878043651581<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [80/221] content loss :1.0476134777069093<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [90/221] content loss :1.07035493850708<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [100/221] content loss :1.0773433148860931<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [110/221] content loss :1.075714612007141<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [120/221] content loss :1.0995955884456634<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [130/221] content loss :1.132514977455139<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [140/221] content loss :1.0869179606437682<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [150/221] content loss :1.1020792543888092<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [160/221] content loss :1.0658072769641875<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [170/221] content loss :1.053791880607605<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [180/221] content loss :1.0880327463150024<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [190/221] content loss :1.0759595513343811<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [200/221] content loss :1.0797491431236268<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [210/221] content loss :1.0831422567367555<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 2 [220/221] content loss :1.0940519213676452<p>
# Epoch: 2 average content loss 1.0840875643950243<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 3 [0/221] content loss :1.1360197067260742<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 3 [10/221] content loss :1.0820533394813538<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 3 [20/221] content loss :1.0628799080848694<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 3 [30/221] content loss :1.0755925178527832<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 3 [40/221] content loss :1.0625411868095398<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 3 [50/221] content loss :1.0577116131782531<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 3 [60/221] content loss :1.0756520450115203<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 3 [70/221] content loss :1.1166022658348083<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 3 [80/221] content loss :1.094583559036255<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 3 [90/221] content loss :1.0808074355125428<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 3 [100/221] content loss :1.081894326210022<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 3 [110/221] content loss :1.0901685774326324<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 3 [120/221] content loss :1.0863240718841554<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_noise.pt<p>Epoch: 3 [130/221] content loss :1.0806560516357422<p>checkpoint s
