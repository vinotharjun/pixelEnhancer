# %%
import sys
sys.path.append("..")
from enhancer import *
from enhancer.options import *
from enhancer.data import * 
from enhancer.utils import *
# %load_ext autoreload
# %autoreload 2

# %%
opt_path = "../configs/smallmodel/mse_train.yml"
# dataloaders = get_dataloader_from_yml(opt_path)
pipeline =load_pipeline_from_yml("../configs/smallmodel/mse_train.yml")
# Out:
# loading dataloader...
# loading models...
# generator is loaded from /notebooks/pixelEnhancer/checkpoints/small_checkpoint_mse_x2.pt
# constructing trainers .....
# loading checkpoint from  /notebooks/pixelEnhancer/checkpoints/small_checkpoint_mse_x2.pt
# Info :check point details are
#  epoch : 153
#  batch : -1

# %%
batch_example = getsample(pipeline["loaders"]["train_dataloader"])

# %%
pipeline["generator"](batch_example["lr"].to(device)).shape
# Out:
# torch.Size([64, 3, 128, 128])

# %%
batch_example["lr"].shape,batch_example["hr"].shape
# Out:
# (torch.Size([64, 3, 64, 64]), torch.Size([64, 3, 128, 128]))

# %%
batch_versus_plot(
    batch_example["lr"],
    batch_example["hr"],
    preupscaling=True,
    figsize = (10,10),
    denormalize=False,
    batch_limit = 4
)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2479: UserWarning: Default upsampling behavior when mode=bicubic is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
torch.autograd.set_detect_anomaly(True)

# %%
pipeline["trainer"].train_model(1,1000)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21' class='' max='999' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       2.10% [21/999 1:12:15<56:04:50]
#     </div>
#
#
# Epoch: 1 average content loss 0.0158509618348696<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 2 average content loss 0.015370913578028028<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 3 average content loss 0.014950437471270561<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 4 average content loss 0.01505481783639301<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 5 average content loss 0.014963819035752253<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 6 average content loss 0.015230998532338575<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 7 average content loss 0.014931615780700336<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 8 average content loss 0.015118403648110953<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 9 average content loss 0.015236022780564698<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 10 average content loss 0.015018622390925884<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 11 average content loss 0.014755672064017166<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 12 average content loss 0.01527204132554206<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 13 average content loss 0.014863724109124054<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 14 average content loss 0.01503147907893766<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 15 average content loss 0.01485752837563103<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 16 average content loss 0.015063726546412165<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 17 average content loss 0.01523926667869091<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 18 average content loss 0.015098062056032095<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 19 average content loss 0.015043425458398733<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 20 average content loss 0.015092220800844106<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
# Epoch: 21 average content loss 0.014868233522230928<p>No validation enabled, so saving epoch checkpoint only<p>checkpoint saved at ../checkpoints/small_checkpoint_mse_x2.pt<p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='55' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/55 00:00<00:00]
#     </div>
