# %%
import sys

sys.path.append("../")
from enhancer.data.lqgt import *

# %%
noise_path = ".././dataset/df2k/Corrupted_noise"

# %%
ds = LQGT(".././dataset/df2k/LR",".././dataset/df2k/HR",noise_path,gtsize=50,normalize_noise=True)

# %%
len(ds.noises)
# Out:
# 2

# %%
d = ds[1]

# %%
plt.imshow(im_convert(d["hr"],denormalize=False))

# %%
plt.imshow(im_convert(d["lr"],denormalize=False))

# %%
Image.open(noise_path+"/"+os.listdir(noise_path)[5]).save("./save.png","JPEG",quality=50)
Image.open("./save.png").save("./save.png")

# %%
d["noise"].shape
# Out:
# torch.Size([3, 12, 12])

# %%
os.listdir(noise_path)[0]
# Out:
# ['0830_000.png',
#  '0830_001.png',
#  '0830_100_2_000.png',
#  '0830_100_2_001.png',
#  '0830_100_4_000.png',
#  '0830_100_4_001.png',
#  '0830_100_6_000.png',
#  '0830_100_6_001.png',
#  '0830_80_4_000.png',
#  '0830_80_4_001.png',
#  'Flickr2K_000016_001.png',
#  'Flickr2K_000036_000.png',
#  'Flickr2K_000038_000.png',
#  'noise.png']

# %%
plt.imshow(im_convert(d["noise"],denormalize=True))

# %%
plt.imshow(cv2.imread(noise_path+"/0830_80_4_000.png"))
