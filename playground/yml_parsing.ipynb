# %%
import sys
sys.path.append("..")
import os

import os.path as osp
import logging
import yaml
from enhancer.utils import OrderedYaml

Loader, Dumper = OrderedYaml()
# %load_ext autoreload
# %autoreload 2

# %%
opt_path = "../configs/train_bigmodel.yml"

# %%
from enhancer.options import *

# %%
from enhancer.data import *

# %%
from enhancer.utils import *

# %%
dic = get_dataloader_from_yml(opt_path)

# %%
getsample(dic["validation_dataloader"])["lr"].shape
# Out:
# torch.Size([1, 3, 64, 64])

# %%
for i,j in enumerate(dic["train_dataset"]):
    print(j["lr"].size())
# Out:
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])
# torch.Size([3, 64, 64])

# %%
plt.imshow(im_convert(dic['train_dataset'][6]["lr"],denormalize=False))

# %%
plt.imshow(im_convert(dic['train_dataset'][6]["hr"],denormalize=False))

# %%
    for key, path in opt["path"].items():
        if path and key in opt["path"] and key != "plt.imshow(im_convert(dic['train_dataset'][6]["lr"],denormalize=False))_load":
            opt["path"][key] = osp.expanduser(path)
    opt["path"]["root"] = osp.abspath(
        osp.join(__file__, osp.pardir, osp.pardir, osp.pardir)
    )

# %%
if opt["datasets"]["train"].get("dataroot_GT", None) is not None:
    print(osp.expanduser(opt["datasets"]["train"]["dataroot_GT"]))
# Out:
# ../datasets/df2k/HR

# %%
osp.join('/media/vinod/Storage/deeplearningProjects/companyfiles', "pixelview","train")

# %%
opt
