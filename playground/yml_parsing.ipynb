# %%
import sys
sys.path.append("..")
import os

import os.path as osp
import logging
import yaml
from enhancer.utils import OrderedYaml

# %load_ext autoreload
# %autoreload 2

# %%
opt_path = "../configs/smallmodel/mse_train.yml"

# %%
from enhancer.options import *
from enhancer.data import *
from enhancer.utils import *

# %%
dic = get_dataloader_from_yml(opt_path)

# %%
len(dic["train_dataset"])
# Out:
# 3550

# %%
for i in dic["train_dataloader"]:
    print(i["lr"].shape)
    print(i["hr"].shape)

# %%
ds = dic["train_dataset"][0]

# %%
plt.imshow(im_convert(ds["lr"],denormalize=False))

# %%
plt.imshow(im_convert(ds["hr"],denormalize=False))

# %%
plt.imshow(im_convert(dic["train_dataset"][6]["lr"],denormalize=False))

# %%
getsample(dic["validation_dataloader"])["lr"].shape
# Out:
# torch.Size([1, 3, 32, 32])

# %%
# for i,j in enumerate(dic["train_dataset"]):
#     print(j["lr"].size())

# %%
res=load_pipeline_from_yml("../configs/smallmodel/mse_train.yml")

# %%
res[-1]

# %%
# res[-1].train_model(1,100,isValidate=False)

# %%
plt.imshow(im_convert(dic['train_dataset'][6]["lr"],denormalize=False))

# %%
plt.imshow(im_convert(dic['train_dataset'][6]["hr"],denormalize=False))
